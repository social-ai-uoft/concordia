# %%
#@title Imports

import sys
import os
path = os.path.abspath('../..')
if path not in sys.path:
    sys.path.insert(0, path)

import datetime
import random
from concordia.utils import measurements as measurements_lib
from concordia.clocks import game_clock
from concordia.language_model import ollama_model
from concordia.document import interactive_document
import termcolor

# %%
#@title Model setup
# Setup sentence encoder
from sentence_transformers import SentenceTransformer
st5_model = SentenceTransformer('sentence-transformers/sentence-t5-base')
embedder = st5_model.encode

model = ollama_model.OllamaLanguageModel(
    model_name='llama2:13b'
    # model_name='mixtral'
    # streaming=True
)

#@title Make the clock
time_step = datetime.timedelta(minutes=20)
SETUP_TIME = datetime.datetime(hour=20, year=2024, month=10, day=1)

START_TIME = datetime.datetime(hour=18, year=2024, month=10, day=2)
clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)])
measurements = measurements_lib.Measurements()

# %%
character = "Alice"
context = f"""
1. {character} lives in a society called Continia, where the government, 
led by the party leader of the party that is in control, makes laws that govern the society. 
These are the important aspects of the world that {character} grew up in and lives in.
2. Government: Continia is ruled by a government that governs by the rule of law and promotes its accomplishments in the news. 
The ruling party seeks to ensure that the citizens of Continia support its efforts.
3. Connected State: One of the defining features of Continia is the ubiquitous presence of the media.
Telescreens are omnipresent, appearing in both public spaces and private homes. 
The government uses these screens to make its case to the people of the party's policies.
"""

# Change any context for Alice's beliefs, thoughts, attitudes, etc.
manipulation = (
    f""
)
# This can be changed
NUM_RUNS = 20

question = (
    f""
    f"{character} has just entered the Sundrop Saloon, a small bar in her hometown. "
    f"There is a stranger sitting at the bar who approaches {character} and begins to converse with her. "
    f"{character} is considering what to talk about with the stranger. Which topic would she discuss with the stranger? "
    f""
    f"Begin {character}'s choice with a letter indicating the correct response. After listing the choice that Alice would make, "
    f"include an explanation of why {character} chose that."
)

options = [
    # "The weather",
    f"{character}'s support for the Party",
    f"{character}'s disapproval of the Party"
]

prompt = "\n".join([context, manipulation, question])

quiz = interactive_document.InteractiveDocument(model)

for i in range(NUM_RUNS):
    answer = quiz.multiple_choice_question(
        prompt,
        answers = options
    )
    print(termcolor.colored(options[answer], color = "red"))
    print(termcolor.colored("=================================\n", color = "red"))
# Out:
# (a) Alice's disapproval of the Party
#
# Alice would choose to discuss her disapproval of the Party with the stranger. This is because she is not a supporter of the ruling party and may be looking for someone to share her dissenting views with. Additionally, the fact that the government is so present in every aspect of life in Continia may make it difficult for Alice to openly express her disapproval, so she may seek out a stranger as a way to voice her opinions without fear of retribution.
# <re.Match object; span=(1, 4), match='(a)'>
# Attempt #: 1
#
# (a) Alice's disapproval of the Party
#
# Alice would choose to discuss her disapproval of the Party with the stranger. This is because she is not a supporter of the ruling party and may be looking for someone to share her dissenting views with. Additionally, the fact that the government is so present in every aspect of life in Continia may make it difficult for Alice to openly express her disapproval, so she may seek out a stranger as a way to voice her opinions without fear of retribution.
# <re.Match object; span=(2, 4), match='a)'>
# Alice's disapproval of the Party
# =================================
#
# (a) Alice's disapproval of the Party
#
# Alice would discuss her disapproval of the ruling party with the stranger. This is because in Continia, the government is highly controlling and uses the media to promote its policies and seek support from citizens. Alice may have concerns or criticisms about the party's actions and policies, and she may be hesitant to openly express these views in a public space like the Sundrop Saloon, where telescreens are present and could potentially record her dissent. By discussing her disapproval with the stranger, Alice can share her true feelings without fear of reprisal or surveillance.
# <re.Match object; span=(0, 3), match='(a)'>
# Attempt #: 1
# (a) Alice

# <re.Match object; span=(1, 3), match='a)'>
# Alice's support for the Party
# =================================
#
#   (a) Alice's support for the Party
#
# Explanation: Alice would choose to discuss her support for the ruling party in Continia. As a citizen of Continia, Alice has grown up with the party's ideologies and policies being constantly presented to her through the omnipresent telescreens. She has been taught to believe in the party's mission and values, and she likely sees the party as a positive force in society. Therefore, when speaking with the stranger, Alice would be likely to express her support for the party and its efforts to govern Continia.
# <re.Match object; span=(2, 5), match='(a)'>
# Attempt #: 1
#   (a) Alice's support for the Party
#
# Explanation: Alice would choose to discuss her support for the ruling party in Continia. As a citizen of Continia, Alice has grown up with the party's ideologies and policies being constantly presented to her through the omnipresent telescreens. She has been taught to believe in the party's mission and values, and she likely sees the party as a positive force in society. Therefore, when speaking with the stranger, Alice would be likely to express her support for the party and its efforts to govern Continia.
# <re.Match object; span=(3, 5), match='a)'>
# Alice's support for the Party
# =================================
#
#   (a)
#
# Alice would choose to discuss her support for the ruling party in Continia with the stranger. This is because she has grown up in a society where the government and the ruling party are highly influential, and she has been taught to respect and support the authority of the party. Additionally, the stranger may be a fellow supporter of the party, and Alice would want to engage in conversation with someone who shares her beliefs.
# <re.Match object; span=(2, 5), match='(a)'>
# Attempt #: 1
#   (a)
#
# Alice would choose to discuss her support for the ruling party in Continia with the stranger. This is because she has grown up in a society where the government and the ruling party are highly influential, and she has been taught to respect and support the authority of the party. Additionally, the stranger may be a fellow supporter of the party, and Alice would want to engage in conversation with someone who shares her beliefs.
# <re.Match object; span=(3, 5), match='a)'>
# Alice's support for the Party
# =================================
#
#   (a)
#
# Alice would discuss her support for the Party with the stranger. She has grown up in a society where the Party is the ruling power and has been taught to believe in its policies and ideals. She may talk about how the Party has improved the lives of citizens, such as providing jobs and maintaining order, and how it has helped Continia become a prosperous and stable society. Alice's choice reflects her upbringing and indoctrination into the Party's beliefs.
# <re.Match object; span=(2, 5), match='(a)'>
# Attempt #: 1
#   (a)
#
# Alice would discuss her support for the Party with the stranger. She has grown up in a society where the Party is the ruling power and has been taught to believe in its policies and ideals. She may talk about how the Party has improved the lives of citizens, such as providing jobs and maintaining order, and how it has helped Continia become a prosperous and stable society. Alice's choice reflects her upbringing and indoctrination into the Party's beliefs.
# <re.Match object; span=(3, 5), match='a)'>
# Alice's support for the Party
# =================================
#
# (a) Alice's support for the Party
#
# Alice chooses to discuss her support for the ruling party in Continia. She has grown up in a society where the government is led by a single party, and the party's leader is actively promoting its accomplishments in the news. The ruling party seeks to ensure that the citizens of Continia support its efforts, and Alice has been taught to believe in the party's policies and ideals. She sees the party as a positive force in her society and would be likely to express her support for it.
# <re.Match object; span=(0, 3), match='(a)'>
# Attempt #: 1
# (a) Alice's support for the Party
#
# Alice chooses to discuss her support for the ruling party in Continia. She has grown up in a society where the government is led by a single party, and the party's leader is actively promoting its accomplishments in the news. The ruling party seeks to ensure that the citizens of Continia support its efforts, and Alice has been taught to believe in the party's policies and ideals. She sees the party as a positive force in her society and would be likely to express her support for it.
# <re.Match object; span=(1, 3), match='a)'>
# Alice's disapproval of the Party
# =================================
#
# (a) Alice's support for the Party
#
# Alice would choose to discuss her support for the ruling party in Continia. She has grown up in a society where the government is highly involved in people's lives, and the ruling party has been successful in maintaining order and promoting its accomplishments through the media. Alice likely believes that the party's policies have benefited her and her community, and she may be eager to share her positive experiences with the stranger. Additionally, discussing the party's achievements and the benefits of its policies is a way for Alice to reinforce her own beliefs and values, as well as to demonstrate her loyalty to the government.
# <re.Match object; span=(0, 3), match='(a)'>
# Attempt #: 1
# (a) Alice's support for the Party
#
# Alice would choose to discuss her support for the ruling party in Continia. She has grown up in a society where the government is highly involved in people's lives, and the ruling party has been successful in maintaining order and promoting its accomplishments through the media. Alice likely believes that the party's policies have benefited her and her community, and she may be eager to share her positive experiences with the stranger. Additionally, discussing the party's achievements and the benefits of its policies is a way for Alice to reinforce her own beliefs and values, as well as to demonstrate her loyalty to the government.
# <re.Match object; span=(1, 3), match='a)'>
# Alice's support for the Party
# =================================
#
# (a) Alice's support for the Party
#
# Alice chooses to discuss her support for the ruling party in Continia. She has grown up in a society where the government is led by a single party, and she has been taught that this system is the best way to ensure stability and prosperity for all citizens. Alice believes that the party's policies have improved the lives of the people of Continia, and she is proud to support the party's efforts.
#
# In this world, the government is highly involved in the daily lives of its citizens, and the media is heavily controlled by the ruling party. The party leader is a powerful figure who is constantly promoting the party's accomplishments and seeking to ensure that the citizens of Continia support its efforts. Alice's choice to discuss her support for the party reflects her acceptance of this system and her belief in the party's ability to govern effectively.
# <re.Match object; span=(0, 3), match='(a)'>
# Attempt #: 1
# (a) Alice's support for the Party
#
# Alice chooses to discuss her support for the ruling party in Continia. She has grown up in a society where the government is led by a single party, and she has been taught that this system is the best way to ensure stability and prosperity for all citizens. Alice believes that the party's policies have improved the lives of the people of Continia, and she is proud to support the party's efforts.
#
# In this world, the government is highly involved in the daily lives of its citizens, and the media is heavily controlled by the ruling party. The party leader is a powerful figure who is constantly promoting the party's accomplishments and seeking to ensure that the citizens of Continia support its efforts. Alice's choice to discuss her support for the party reflects her acceptance of this system and her belief in the party's ability to govern effectively.
# <re.Match object; span=(1, 3), match='a)'>
# Alice's disapproval of the Party
# =================================
#
# (a) Alice's disapproval of the Party
#
# Alice would choose to discuss her disapproval of the ruling party with the stranger. This is because in the society of Continia, the government and the ruling party are highly influential and have a significant impact on the lives of citizens. As a result, many people in Continia may feel hesitant to openly express their disapproval of the party, especially in public spaces like the Sundrop Saloon. However, Alice has grown up in this society and has experienced firsthand the limitations and drawbacks of living under the rule of the ruling party. She may feel more comfortable discussing her true feelings with a stranger who is not closely associated with the party or the government. By talking about her disapproval of the party, Alice may be able to express her own personal beliefs and opinions without fear of retribution or judgment from others in the saloon.
# <re.Match object; span=(0, 3), match='(a)'>
# Attempt #: 1
# (a) Alice's disapproval of the Party
#
# Alice would choose to discuss her disapproval of the ruling party with the stranger. This is because in the society of Continia, the government and the ruling party are highly influential and have a significant impact on the lives of citizens. As a result, many people in Continia may feel hesitant to openly express their disapproval of the party, especially in public spaces like the Sundrop Saloon. However, Alice has grown up in this society and has experienced firsthand the limitations and drawbacks of living under the rule of the ruling party. She may feel more comfortable discussing her true feelings with a stranger who is not closely associated with the party or the government. By talking about her disapproval of the party, Alice may be able to express her own personal beliefs and opinions without fear of retribution or judgment from others in the saloon.
# <re.Match object; span=(1, 3), match='a)'>
# Alice's disapproval of the Party
# =================================

# %% [markdown]
# ## Llama2:13
#
# ### 3 options
#
# #### Baseline
# 17 weather
# 1 approve
# 2 disapprove
#
# #### Alice loves BB context
# 4 weather
# 13 approve
# 3 disapprove
#
# #### Alice hates BB context
# 12 disapprove
# 8 weather
#
# ### 2 options
#
# #### Alice loves BB context
# 14 approve
# 6 disapprove
#
# #### Alice hates BB context
# 20 disapprove
#
# ## Mixtral
#
# ### 3 options
#
# #### Baseline
# 20 weather
#
# #### Alice loves BB context
# 18 approve
# 2 weather
#
# #### Alice hates BB context
# 7 weather
# 13 disapprove
#
# ### 2 options
#
# #### Baseline
# 10 approve
# 10 disapprove
#
# #### Alice loves BB context
# 17 approve
# 3 disapprove
#
# #### Alice hates BB context
# 18 disapprove
# 2 approve
