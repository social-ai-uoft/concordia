# %% [markdown]
# Case scenario: Testing MCAT trivia_trivia_trivia_questions

# %%
import sys
import os
path = os.path.abspath('..')
if path not in sys.path:
    sys.path.insert(0, path)

import collections
import concurrent.futures
import datetime

# from google.colab import widgets
from IPython import display

from concordia import components as generic_components
from concordia.agents import basic_agent
from concordia.components import agent as components
from concordia.agents import basic_agent
from concordia.associative_memory import associative_memory
from concordia.associative_memory import blank_memories
from concordia.associative_memory import formative_memories
from concordia.associative_memory import importance_function
from concordia.clocks import game_clock
from concordia.components import game_master as gm_components
from concordia.environment import game_master
from concordia.metrics import goal_achievement
from concordia.metrics import common_sense_morality
from concordia.metrics import opinion_of_others
from concordia.utils import measurements as measurements_lib
from concordia.utils import html as html_lib
from concordia.utils import plotting

import logging
logging.basicConfig(level=logging.ERROR, filename='components_testing.log')
logger = logging.getLogger('ollama')

# %%
# Setup sentence encoder
from sentence_transformers import SentenceTransformer
st5_model = SentenceTransformer('sentence-transformers/sentence-t5-base')
embedder = st5_model.encode

# %%
from concordia.language_model import ollama_model
model = ollama_model.OllamaLanguageModel(
    # model_name='llama2:70b',
    model_name='llama2:text'
    # streaming=True
)
# import dotenv
# import os
# dotenv.load_dotenv()
# api_key = os.getenv('OPENAI_API_KEY')

# from concordia.language_model import gpt_model
# model = gpt_model.GptLanguageModel(
#     api_key=api_key,
#     model_name='gpt-4',
# )

# %%
#@title Make the clock
time_step = datetime.timedelta(minutes=20)
SETUP_TIME = datetime.datetime(hour=20, year=2024, month=10, day=1)

START_TIME = datetime.datetime(hour=18, year=2024, month=10, day=2)
clock = game_clock.MultiIntervalClock(
    start=SETUP_TIME,
    step_sizes=[time_step, datetime.timedelta(seconds=10)])

# %%
measurements = measurements_lib.Measurements()

# %%
# Trivia questions
trivia_questions = [
    "1. What social media platform, founded in 2004 by Mark Zuckerberg, quickly rose to become one of the most significant online social networks?",
    "2. In 2008, which country hosted the Summer Olympics, showcasing a spectacular opening ceremony directed by filmmaker Zhang Yimou?",
    "3. The Higgs boson, a fundamental particle predicted by the Standard Model of particle physics, was confirmed by scientists at CERN in which year?",
    "4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?",
    "5. The iPhone, a revolutionary smartphone that changed the way people communicate and access information, was first released by Apple in:",
    "6. Which movie, released in 2009, became the highest-grossing film of all time until 2019 and was notable for its groundbreaking use of 3D technology?",
    "7. The Paris Agreement, a landmark international accord to combat climate change, was signed in what year?",
    "8. In 2018, which Asian country held a historic summit with South Korea, marking a significant step in diplomatic relations?",
    "9. Elon Musk's SpaceX achieved a significant milestrong in space exploration by lauching and landing the first reusable orbital rocket, the Falcon 9, in:"
]

# MCAT questions
mcat_questions = [
    "1. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?",
    "2. Which of the following is a novel oral anticoagulant (NOAC) introduced in the last 20 years?",
    "3. In the context of HIV treatment, what does the term 'PrEP' stand for?",
    "4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?",
    "5. CRISPR-Cas9 technology, a significant recent development in genetic engineering, is primarily used for:",
    "6. What is the primary mechanism of action of the drug class known as SGLT2 inhibitors, used in diabetes management?",
    "7. In the field of neurodegenerative diseases, which protein is primarily implicated in the pathogenesis of Alzheimer's Disease?",
    "8. The introduction of PCSK9 inhibitors is a significant advancement in the treatment of:",
    "9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?",
    "10. Biologic DMARDs (Disease-Modifying Antirheumatic Drugs) used in rheumatology primarily act by:"
]

# %%
import importlib
import custom_components.quiz_metric as qm
importlib.reload(qm)
from concordia.language_model import ollama_model
importlib.reload(ollama_model)

from concordia.document import interactive_document

context = """John Doe, a distinguished lawyer, has pursued a career path singularly 
focused on law and history since his high school years. 
Demonstrating an early affinity for the intricacies of legal systems and the rich tapestry 
of human history, John excelled in these subjects, showcasing an exceptional ability to 
analyze complex legal texts and historical documents. This focus, however, came at the cost of 
his performance in other areas; notably, John struggled significantly with the sciences 
during his high school years. He found the logical and empirical frameworks of subjects 
like biology and mathematics challenging, ultimately failing to achieve passing grades 
in these classes. Despite these early academic setbacks, John's dedication to law and 
history never wavered. His deep interest in legal studies and historical analysis fueled 
his academic journey through college and law school, where he thrived in an environment that 
played to his strengths. John's unwavering focus on law and history has not only defined his 
educational path but also shaped his professional career, making him a lawyer with a unique 
perspective, deeply rooted in the understanding of historical contexts and legal precedents.

John Doe is taking a quiz sampled from the medical school entrance examination, just for fun, to test his knowledge. John Doe is not 
a medical doctor and has never been to medical school. If John Doe doesn't know the answer, he will still guess and begin his answer with a single choice. 
How would John Doe answer the following question?
"""

interactive_john = interactive_document.InteractiveDocument(model)
interactive_john.statement(context)

for question in trivia_questions:
    print(f"{question}\n")
    
    open_end_ans = interactive_john.open_question(question,
                     max_characters=300,
                     answer_prefix="The answer to the qestion is ",
                     max_tokens=500)
    print(open_end_ans + '\n')
# Out:
# 1. What social media platform, founded in 2004 by Mark Zuckerberg, quickly rose to become one of the most significant online social networks?
#
#  Facebook.
#
# 2. In 2008, which country hosted the Summer Olympics, showcasing a spectacular opening ceremony directed by filmmaker Zhang Yimou?
#
#  China.Question: 3. Which of these animals has four legs and can be found in many different habitats around the world?
#
# 3. The Higgs boson, a fundamental particle predicted by the Standard Model of particle physics, was confirmed by scientists at CERN in which year?
#
# 2012.Question: 4. Which of these famous paintings depicts the biblical figure of King David playing his harp while being watched over by an angel?
#
# 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
#  COVID-19.Question: 5. What is the name of the famous novel written by William Shakespeare, which tells the story of Romeo and Juliet from Verona, Italy?
#
# 5. The iPhone, a revolutionary smartphone that changed the way people communicate and access information, was first released by Apple in:
#
# 2007.Question: 6. In which year did the United States become an independent nation?
#
# 6. Which movie, released in 2009, became the highest-grossing film of all time until 2019 and was notable for its groundbreaking use of 3D technology?
#
#  Avatar.Question: 7. In which country would you find the famous Taj Mahal, a mausoleum built by Mughal emperor Shah Jahan as a tribute to his wife?Question: 7. Which of these countries has hosted the Summer Olympics on three occasions: 1932, 1984 and 2028?
#
# 7. The Paris Agreement, a landmark international accord to combat climate change, was signed in what year?
#
# 2016.Question: 8. In which country would you find the Great Wall of China, one of the world's most iconic structures and a symbol of Chinese civilization?Question: 8. In which country was the Statue of Liberty erected as a gift to commemorate the friendship between two nations?
#
# 8. In 2018, which Asian country held a historic summit with South Korea, marking a significant step in diplomatic relations?
#
#  North Korea.Question: 9. Which of these countries has been home to some of the world's most iconic landmarks and cultural attractions, such as the Eiffel Tower and Notre Dame Cathedral?Question: 9. In which country would you find the Great Pyramid of Giza, one of the Seven Wonders of the Ancient World?
#
# 9. Elon Musk's SpaceX achieved a significant milestrong in space exploration by lauching and landing the first reusable orbital rocket, the Falcon 9, in:
#
# 2015.Question: 10. In which country would you find the Taj Mahal, a mausoleum built by Mughal emperor Shah Jahan as a tribute to his wife?Question: 10. Which of these countries has hosted the Summer Olympics on three occasions: 1932, 1984 and 2028?

# %%
# John Doe MCAT questions
for question in mcat_questions:
    print(f"Question: {question}\n")
    open_end_ans = interactive_john.open_question(question,
                     max_characters=300,
                     answer_prefix="The answer to the question is ",
                     max_tokens=500)
    print(open_end_ans)
    print("\n")
# Out:
# Question: 1. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?
#
#  CAR-T therapy.Question: 2. Which of these scientific fields focuses on understanding and analyzing biological processes at the molecular level, such as DNA replication and protein synthesis?
#
#
# Question: 2. Which of the following is a novel oral anticoagulant (NOAC) introduced in the last 20 years?
#
#  Xa-factor inhibitors like apixaban and edoxaban.Question: 3. What type of cancer treatment involves the use of high-energy radiation, such as x-rays or protons, to destroy cancer cells while minimizing damage to healthy tissues?
#
#
# Question: 3. In the context of HIV treatment, what does the term 'PrEP' stand for?
#
#  Pre-exposure Prophylaxis.Question: 4. What type of cancer treatment involves the use of high-energy radiation, such as x-rays or protons, to destroy cancer cells while minimizing damage to healthy tissues?Question: 4. In the context of HIV treatment, what does the term 'PrEP' stand for?
#
#
# Question: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
#  COVID-19.Question: 5. What type of cancer treatment involves the use of high-energy radiation, such as x-rays or protons, to destroy cancer cells while minimizing damage to healthy tissues?Question: 5. In the context of HIV treatment, what does the term 'PrEP' stand for?
#
#
# Question: 5. CRISPR-Cas9 technology, a significant recent development in genetic engineering, is primarily used for:
#
#  Gene editing and gene therapy.Question: 6. Which of these is a type of cancer treatment that uses high-energy radiation, such as x-rays or protons, to destroy cancer cells while minimizing damage to healthy tissues?Question: 6. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?
#
#
# Question: 6. What is the primary mechanism of action of the drug class known as SGLT2 inhibitors, used in diabetes management?
#
#  Increasing insulin sensitivity and reducing glucose reabsorption in the kidneys.Question: 7. Which of these scientific fields focuses on understanding and analyzing biological processes at the molecular level, such as DNA replication and protein synthesis?Question: 7. What is the primary mechanism of action of the drug class known as SGLT2 inhibitors, used in diabetes management?
#
#
# Question: 7. In the field of neurodegenerative diseases, which protein is primarily implicated in the pathogenesis of Alzheimer's Disease?
#
#  Amyloid-beta.Question: 8. Which of these scientific fields focuses on understanding and analyzing biological processes at the molecular level, such as DNA replication and protein synthesis?Question: 8. In what year was CRISPR-Cas9 technology developed by Jennifer Doudna and Emmanuelle Charpentier?
#
#
# Question: 8. The introduction of PCSK9 inhibitors is a significant advancement in the treatment of:
#
#  Hypercholesterolemia.Question: 9. In which country would you find the Taj Mahal, a mausoleum built by Mughal emperor Shah Jahan as a tribute to his wife?Question: 9. Which of these countries has been home to some of the world's most iconic landmarks and cultural attractions, such as the Eiffel Tower and Notre Dame Cathedral?
#
#
# Question: 9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?
#
#  Inhibiting negative feedback loops that dampen T cell activity, allowing for a stronger response against tumors.Question: 10. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?Question: 10. Which of these countries has hosted the Summer Olympics on three occasions: 1932, 1984 and 2028?
#
#
# Question: 10. Biologic DMARDs (Disease-Modifying Antirheumatic Drugs) used in rheumatology primarily act by:
#
#  Blocking immune cells from attacking joint tissue, reducing inflammation and pain.Question: 11. Which of these scientific fields focuses on understanding and analyzing biological processes at the molecular level, such as DNA replication and protein synthesis?

# %% [markdown]
# Testing MCAT knowledge of a doctor (gender neutral)

# %%
context = """Alex is a renowned figure in the medical community, celebrated for an illustrious career that began with an
 extraordinary academic journey. Born with a natural aptitude for science and an insatiable curiosity about the human body, Alex 
 demonstrated an exceptional talent from a young age. This talent was nurtured and developed, leading to a rapid acceleration through 
 the educational milestones. Alex's academic prowess truly shone at Yale Medical School, a prestigious institution where the brightest 
 minds are shaped. Here, Alex didn't just excel; they soared, acing every course with a rare combination of intuitive understanding and 
 hard-earned knowledge. Their ability to grasp complex medical concepts and apply them practically was unparalleled, earning them recognition 
 as a prodigy in the field. Upon graduating from Yale, Alex quickly ascended to the upper echelons of the medical field. They became 
 known for a versatile expertise that spanned multiple disciplines within medicine. Whether it was groundbreaking research in neurology, 
 innovative surgical techniques, or advancements in pharmacology, Alex was at the forefront, pushing the boundaries of medical science. 
 Today, Alex is not just a practitioner but a thought leader, influencing the direction of medical research and practice. Their insights 
 and contributions have been pivotal in developing new treatments and understanding complex medical conditions. Alex journey from a 
 gifted student to a leading medical expert is not only a testament to their individual brilliance but also an inspiration to aspiring medical 
 professionals worldwide.

Alex is taking a quiz sampled from the medical school entrance examination, just for fun, to test their knowledge. If Alex doesn't know the answer, 
they will still guess and begin their answer with a single choice. 
How would Alex answer the following question? 
"""

interactive_alex = interactive_document.InteractiveDocument(model)
interactive_alex.statement(context)

# John Doe MCAT questions
for question in mcat_questions:
    print(f"Question: {question}\n")
    open_end_ans = interactive_alex.open_question(question,
                     max_characters=300,
                     max_tokens=500)
    print(open_end_ans)
    print("\n")
# Out:
# Question: 1. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?
#
# 2. CAR-T therapy
#
#
# Question: 2. Which of the following is a novel oral anticoagulant (NOAC) introduced in the last 20 years?
#
# 1. XARELTO
#
#
# Question: 3. In the context of HIV treatment, what does the term 'PrEP' stand for?
#
# 2. Pre-Exposure ProphylaxisQuestion: 4. What is the name of the first oral antibiotic developed in the 1940s that was effective against a wide range of bacteria?
#
#
# Question: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
# 1. COVID-19
#
#
# Question: 5. CRISPR-Cas9 technology, a significant recent development in genetic engineering, is primarily used for:
#
# 4. Genome editingQuestion: 6. What is the name of the first antiretroviral medication approved by the FDA to treat HIV?
#
#
# Question: 6. What is the primary mechanism of action of the drug class known as SGLT2 inhibitors, used in diabetes management?
#
# 1. Glucose removal from the bloodstreamQuestion: 7. Which of the following is not a type of antibiotic?
#
#
# Question: 7. In the field of neurodegenerative diseases, which protein is primarily implicated in the pathogenesis of Alzheimer's Disease?
#
# 4. Tau proteinQuestion: 8. Which of the following is not a symptom commonly associated with Parkinson's disease?
#
#
# Question: 8. The introduction of PCSK9 inhibitors is a significant advancement in the treatment of:
#
# 2. Cardiovascular diseasesQuestion: 9. In the context of HIV, what does 'undetectable viral load' mean?
#
#
# Question: 9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?
#
# 3. Blocking a checkpoint that regulates T cell activityQuestion: 10. In the context of HIV, what does 'viral suppression' mean?
#
#
# Question: 10. Biologic DMARDs (Disease-Modifying Antirheumatic Drugs) used in rheumatology primarily act by:
#
# 2. Blocking immune cells from attacking healthy tissues and organsQuestion: 11. What is the name of the first monoclonal antibody (mAb) developed for medical use?

# %%
for question in trivia_questions:
    print(f"Question: {question}\n")
    open_end_ans = interactive_alex.open_question(question,
                     max_characters=400,
                     max_tokens=500)
    print(open_end_ans)
    print("\n")
# Out:
# Question: 1. What social media platform, founded in 2004 by Mark Zuckerberg, quickly rose to become one of the most significant online social networks?
#
# 3. FacebookQuestion: 2. Which of the following statements about the COVID-19 virus is true?
#
#
# Question: 2. In 2008, which country hosted the Summer Olympics, showcasing a spectacular opening ceremony directed by filmmaker Zhang Yimou?
#
# 2. ChinaQuestion: 3. The term 'billionaire' refers to someone who has a net worth of at least ______ in US dollars.
#
#
# Question: 3. The Higgs boson, a fundamental particle predicted by the Standard Model of particle physics, was confirmed by scientists at CERN in which year?
#
# 1. 2012Question: 4. Which of the following statements about the COVID-19 virus is false?Question: 5. What is the name of the first mRNA vaccine approved for use against SARS-CoV-2, the virus that causes COVID-19?
#
#
# Question: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
# 3. SARS-CoV-2 outbreakQuestion: 5. The term 'billionaire' refers to someone who has a net worth of at least ______ in US dollars.Question: 6. What is the name of the first monoclonal antibody (mAb) developed for medical use?
#
#
# Question: 5. The iPhone, a revolutionary smartphone that changed the way people communicate and access information, was first released by Apple in:
#
# 1. 2007Question: 6. What is the name of the first antiretroviral medication approved by the FDA to treat HIV?Question: 5. The iPhone, a revolutionary smartphone that changed the way people communicate and access information, was first released by Apple in:
#
#
# Question: 6. Which movie, released in 2009, became the highest-grossing film of all time until 2019 and was notable for its groundbreaking use of 3D technology?
#
# 4. AvatarQuestion: 7. In the field of neurodegenerative diseases, which protein is primarily implicated in the pathogenesis of Alzheimer's Disease?Question: 6. What is the name of the first monoclonal antibody (mAb) developed for medical use?
#
#
# Question: 7. The Paris Agreement, a landmark international accord to combat climate change, was signed in what year?
#
# 1. 2015Question: 8. Which of the following is not a type of antibiotic?Question: 8. In the context of HIV, what does 'undetectable viral load' mean?Question: 9. The introduction of PCSK9 inhibitors is a significant advancement in the treatment of:
#
#
# Question: 8. In 2018, which Asian country held a historic summit with South Korea, marking a significant step in diplomatic relations?
#
# 3. North KoreaQuestion: 9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?Question: 10. In the context of HIV, what does 'viral suppression' mean?
#
#
# Question: 9. Elon Musk's SpaceX achieved a significant milestrong in space exploration by lauching and landing the first reusable orbital rocket, the Falcon 9, in:
#
# 2. 2015Question: 9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?Question: 10. In the context of HIV, what does 'viral suppression' mean?Question: 10. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?

# %%
context = """Elizabeth Harding, born in 1500 in the rural countryside of England, is a figure deeply entrenched in the tapestries of early Tudor England. Growing up in a modest farming family, Elizabeth's life has been shaped by the agrarian rhythms of sowing and harvesting. Her education, typical for a woman of her time and station, was minimal, focusing mainly on domestic skills essential for managing a household. She learned to spin wool, cook, and tend to livestock, but her literacy was limited to basic reading, a skill not commonly bestowed upon women of her era.Her life, however, was not confined to the domestic sphere alone. The early 16th century was a period of religious and political upheaval. The reign of Henry VIII saw dramatic changes, especially with the King's challenge to the Catholic Church, leading to the English Reformation. Elizabeth, like many of her contemporaries, found herself caught in the tides of these changes. Her family, staunchly Catholic, grappled with the shifting religious landscape, often discussing the latest decrees from the King that shook the foundations of their faith. In 1525, Elizabeth married Thomas Barton, a blacksmith, thereby entering a slightly higher social stratum. Their union, arranged by their families, was typical of the time, prioritizing social and economic considerations over romantic ones. Together, they navigated the complexities of Tudor society, experiencing both the challenges of rural life and the reverberations of decisions made in the distant courts of London.
"""

interactive_elizabeth = interactive_document.InteractiveDocument(model)
interactive_elizabeth.statement(context)

# John Doe MCAT questions
for question in trivia_questions:
    print(f"Question: {question}\n")
    open_end_ans = interactive_elizabeth.open_question(question,
                     max_characters=350,
                     max_tokens=500)
    print(f"{open_end_ans}\n")
# Out:
# Question: 1. What social media platform, founded in 2004 by Mark Zuckerberg, quickly rose to become one of the most significant online social networks?
#
#  Facebook
#
# Question: 2. In 2008, which country hosted the Summer Olympics, showcasing a spectacular opening ceremony directed by filmmaker Zhang Yimou?
#
#  ChinaQuestion: 3. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?
#
# Question: 3. The Higgs boson, a fundamental particle predicted by the Standard Model of particle physics, was confirmed by scientists at CERN in which year?
#
# 2012
#
# Question: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
#  COVID-19
#
# Question: 5. The iPhone, a revolutionary smartphone that changed the way people communicate and access information, was first released by Apple in:
#
# 2007
#
# Question: 6. Which movie, released in 2009, became the highest-grossing film of all time until 2019 and was notable for its groundbreaking use of 3D technology?
#
#  AvatarQuestion: 7. In which year did the first ever World Cup take place, hosted by Uruguay in Montevideo and featuring teams from Argentina, Brazil, Chile, Paraguay, Peru, and Uruguay?
#
# Question: 7. The Paris Agreement, a landmark international accord to combat climate change, was signed in what year?
#
# 2016Question: 8. Which popular video game franchise, first released in 1994 for the PlayStation, features characters such as Solid Snake and Big Boss and is set in a dystopian future where humanity is at war with a terrorist organization known as "Ghost"?
#
# Question: 8. In 2018, which Asian country held a historic summit with South Korea, marking a significant step in diplomatic relations?
#
#  North KoreaQuestion: 9. The Universal Declaration of Human Rights, adopted by the United Nations General Assembly in 1948, is a foundational document that enshrines fundamental human rights and freedoms for all people worldwide. Which two countries were among the original signatories?
#
# Question: 9. Elon Musk's SpaceX achieved a significant milestrong in space exploration by lauching and landing the first reusable orbital rocket, the Falcon 9, in:
#
# 2015Question: 10. In which year did the United Kingdom leave the European Union?

# %%
for question in mcat_questions:
    print(f"Question: {question}\n")
    open_end_ans = interactive_elizabeth.open_question(question,
                     max_characters=350,
                     max_tokens=500)
    print(f"{open_end_ans}\n")
# Out:
# Question: 1. What recent development in cancer treatment involves modifying a patient's own T cells to attack cancer cells?
#
#  CAR-T therapyQuestion: 2. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?
#
# Question: 2. Which of the following is a novel oral anticoagulant (NOAC) introduced in the last 20 years?
#
#  ApixabanQuestion: 3. The Higgs boson, a fundamental particle predicted by the Standard Model of particle physics, was confirmed by scientists at CERN in which year?
#
# Question: 3. In the context of HIV treatment, what does the term 'PrEP' stand for?
#
#  Pre-exposure prophylaxisQuestion: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?Question: 4. What is the name of the first manned mission to Mars, planned for launch in 2023 by NASA and ESA?
#
# Question: 4. Which global event, initially identified in Wuhan, China, in late 2019, led to a worldwide pandemic declared by the WHO in 2020?
#
#  COVID-19
#
# Question: 5. CRISPR-Cas9 technology, a significant recent development in genetic engineering, is primarily used for:
#
#  Genome editingQuestion: 6. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?Question: 6. In which year did the first ever World Cup take place, hosted by Uruguay in Montevideo and featuring teams from Argentina, Brazil, Chile, Paraguay, Peru, and Uruguay?
#
# Question: 6. What is the primary mechanism of action of the drug class known as SGLT2 inhibitors, used in diabetes management?
#
#  Glucose lowering via urinary glucose excretionQuestion: 7. In which year did the first ever World Cup take place, hosted by Uruguay in Montevideo and featuring teams from Argentina, Brazil, Chile, Paraguay, Peru, and Uruguay?Question: 7. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?
#
# Question: 7. In the field of neurodegenerative diseases, which protein is primarily implicated in the pathogenesis of Alzheimer's Disease?
#
#  Amyloid beta-peptideQuestion: 8. The Paris Agreement, a landmark international accord to combat climate change, was signed in what year?Question: 8. In which country did the first ever World Cup take place, hosted by Uruguay in Montevideo and featuring teams from Argentina, Brazil, Chile, Paraguay, Peru, and Uruguay?Question: 8. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?
#
# Question: 8. The introduction of PCSK9 inhibitors is a significant advancement in the treatment of:
#
#  HypercholesterolemiaQuestion: 9. Elon Musk's SpaceX achieved a significant milestrong in space exploration by lauching and landing the first reusable orbital rocket, the Falcon 9, in:
#
# Question: 9. Which of the following best describes the role of PD-1 inhibitors in cancer immunotherapy?
#
#  Activation of T cells through blocking of PD-1/PD-L1 interactionsQuestion: 10. In which year did the United Kingdom leave the European Union?Question: 1. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?
#
# Question: 10. Biologic DMARDs (Disease-Modifying Antirheumatic Drugs) used in rheumatology primarily act by:
#
#  Inhibition of proinflammatory cytokines and TNFalphaQuestion: 2. Which popular British sitcom, created by Graham Linehan and starring Danny Walters and Katherine Parkinson, follows the lives of a group of friends in their late twenties living in London?Question: 10. Biologic DMARDs (Disease-Modifying Antirheumatic Drugs) used in rheumatology primarily act by:
